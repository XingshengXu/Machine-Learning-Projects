# %% [markdown]
# #### Gaussian Discriminant Analysis Classification on Synthetic Data

# %%
import pandas as pd
from sklearn.datasets import make_blobs
from sklearn.preprocessing import MinMaxScaler
from Gaussian_Discriminant_Analysis import GaussianDiscriminant
from GLA_utils import *

# %% [markdown]
# ##### 1. Display plots that illustrate a GDA classification on manually generated two-class data

# %%
# %matplotlib widget
interactive_data_collection_classification()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ##### 2. Display plots that illustrate a GDA classification on linearly separable multi-class data

# %%
X, y = make_blobs(n_samples=200, n_features=2, centers=2,
                  random_state=0, cluster_std=0.4)

# Normalization of input data
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# Fit the model
gda = GaussianDiscriminant()
gda.fit(X, y)

# Plot the data
plot_class_distributions(gda)

# %% [markdown]
# #### Gaussian Discriminant Analysis for Classificating Marketing Target

# %%
# Load Data
market_data = pd.read_csv('../dataset/Social_Network_Ads.csv', header=0)

# Remove the First Column
market_data = market_data.drop(market_data.columns[0], axis=1)

# Training Set
train_X = market_data.iloc[0:300, 0:-1].values
train_Y = market_data.iloc[0:300:, -1].values

# Test Set
test_X = market_data.iloc[300:, 0:-1].values
test_Y = market_data.iloc[300:, -1].values

# %%
# Fit the model
gda = GaussianDiscriminant()
gda.fit(train_X, train_Y)

pred_y = gda.predict_class(test_X)

# Plot the data
plot_class_distributions(gda)

# Performance Test
evaluate_model(test_Y, pred_y)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.95      0.73        38
#            1       0.95      0.61      0.75        62
#
#     accuracy                           0.74       100
#    macro avg       0.77      0.78      0.74       100
# weighted avg       0.82      0.74      0.74       100
