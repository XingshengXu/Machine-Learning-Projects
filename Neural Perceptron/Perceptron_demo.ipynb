# %% [markdown]
# #### Implement Single Layer Perceptron Classifier on Synthetic Data

# %%
import idx2numpy
import pandas as pd
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from Single_Layer_Perceptron import SLPClassifier
from Multi_Layer_Perceptron import MLPClassifier
from Perceptron_utils import *

# %%
# Generate the data
X,y = make_blobs(n_samples=1000, n_features=2, centers=3, cluster_std=1, random_state=0)

# Split the data into training and test sets
train_X, test_X, train_Y, test_Y = train_test_split(X, y, test_size=0.3, random_state=0)

#Fit the model
slp = SLPClassifier(learning_rate=0.001, max_iterations=1000)
slp.fit(train_X, train_Y)

# Plot the data
plot_cost_vs_iteration(slp)

# Performance Test
pred_y = slp.predict_class(test_X)
evaluate_model(test_Y, pred_y)

# Plot the decision boundary and the true labels
print('Decision Boundary with Training Data')
create_contour_plot(slp, train_X, train_Y, resolution=200)

print('Decision Boundary with Testing Data')
create_contour_plot(slp, test_X, test_Y, resolution=200)
# Out:
# 1 iterations
# 2 iterations
# 3 iterations
# 4 iterations
# 5 iterations
# 6 iterations
# 7 iterations
# 8 iterations
# 9 iterations
# 10 iterations
# 11 iterations
# 12 iterations
# 13 iterations
# 14 iterations
# 15 iterations
# 16 iterations
# 17 iterations
# 18 iterations
# 19 iterations
# 20 iterations
# 21 iterations
# 22 iterations
# 23 iterations
# 24 iterations
# 25 iterations
# 26 iterations
# 27 iterations
# 28 iterations
# 29 iterations
# 30 iterations
# 31 iterations
# 32 iterations
# 33 iterations
# 34 iterations
# 35 iterations
# 36 iterations
# 37 iterations
# 38 iterations
# 39 iterations
# 40 iterations
# 41 iterations
# 42 iterations
# 43 iterations
# 44 iterations
# 45 iterations
# 46 iterations
# 47 iterations
# 48 iterations
# 49 iterations
# 50 iterations
# 51 iterations
# 52 iterations
# 53 iterations
# 54 iterations
# 55 iterations
# 56 iterations
# 57 iterations
# 58 iterations
# 59 iterations
# 60 iterations
# 61 iterations
# 62 iterations
# 63 iterations
# ...

# %% [markdown]
# #### Implement Single Layer Perceptron Classifier on Handwritten Digit Recognition

# %%
# Load Training and Testing Data Sets
train_X = idx2numpy.convert_from_file(
    '../dataset/train-images.idx3-ubyte')
train_Y = idx2numpy.convert_from_file(
    '../dataset/train-labels.idx1-ubyte')
test_X = idx2numpy.convert_from_file(
    '../dataset/t10k-images.idx3-ubyte')
test_Y = idx2numpy.convert_from_file(
    '../dataset/t10k-labels.idx1-ubyte')

# %%
# Preprocess the image into input data format
train_X = preprocess_image(train_X)
test_X = preprocess_image(test_X)

# Fit the model
slp = SLPClassifier(learning_rate=0.00001, max_iterations=1000)
slp.fit(train_X, train_Y)

pred_y = slp.predict_class(test_X)

# Plot the data
plot_cost_vs_iteration(slp)

# Performance Test
evaluate_model(test_Y, pred_y)

# %% [markdown]
# #### Implement Single Layer Perceptron Classifier on Predicting Marketing Target

# %%
# Load Data
market_data = pd.read_csv('../dataset/Social_Network_Ads.csv', header=0)

# Remove the First Column
market_data = market_data.drop(market_data.columns[0], axis=1)

# Training Set
train_X = market_data.iloc[0:300, 0:-1].values
train_Y = market_data.iloc[0:300:, -1].values

# Test Set
test_X = market_data.iloc[300:, 0:-1].values
test_Y = market_data.iloc[300:, -1].values

# Standardize the Features for Both Training Set and Test Set
scaler = StandardScaler()

train_X = scaler.fit_transform(train_X)
test_X = scaler.transform(test_X)

# %%
# Fit the model
slp = SLPClassifier(learning_rate=0.02, max_iterations=100)
slp.fit(train_X, train_Y)

# Plot the data
plot_cost_vs_iteration(slp)

# Performance Test
pred_y = slp.predict_class(test_X)
evaluate_model(test_Y, pred_y)

# Plot the decision boundary and the true labels
print('Decision Boundary with Training Data')
create_contour_plot(slp, train_X, train_Y, resolution=200)

print('Decision Boundary with Testing Data')
create_contour_plot(slp, test_X, test_Y, resolution=200)
# Out:
# 1 iterations
# 2 iterations
# 3 iterations
# 4 iterations
# 5 iterations
# 6 iterations
# 7 iterations
# 8 iterations
# 9 iterations
# 10 iterations
# 11 iterations
# 12 iterations
# 13 iterations
# 14 iterations
# 15 iterations
# 16 iterations
# 17 iterations
# 18 iterations
# 19 iterations
# 20 iterations
# 21 iterations
# 22 iterations
# 23 iterations
# 24 iterations
# 25 iterations
# 26 iterations
# 27 iterations
# 28 iterations
# 29 iterations
# 30 iterations
# 31 iterations
# 32 iterations
# 33 iterations
# 34 iterations
# 35 iterations
# 36 iterations
# 37 iterations
# 38 iterations
# 39 iterations
# 40 iterations
# 41 iterations
# 42 iterations
# 43 iterations
# 44 iterations
# 45 iterations
# 46 iterations
# 47 iterations
# 48 iterations
# 49 iterations
# 50 iterations
# 51 iterations
# 52 iterations
# 53 iterations
# 54 iterations
# 55 iterations
# 56 iterations
# 57 iterations
# 58 iterations
# 59 iterations
# 60 iterations
# 61 iterations
# 62 iterations
# 63 iterations
# ...

# %% [markdown]
# #### Implement Multi Layer Perceptron Classifier on Synthetic Data

# %%
# Generate the data
X,y = make_blobs(n_samples=1000, n_features=2, centers=3, cluster_std=1, random_state=0)

# Split the data into training and test sets
train_X, test_X, train_Y, test_Y = train_test_split(X, y, test_size=0.3, random_state=0)

#Fit the model
mlp = MLPClassifier(learning_rate=0.01, hidden_node_number=10, max_iterations=1000)
mlp.fit(train_X, train_Y)

# Plot the data
plot_cost_vs_iteration(mlp)

# Performance Test
pred_y = mlp.predict_class(test_X)
evaluate_model(test_Y, pred_y)

# Plot the decision boundary and the true labels
print('Decision Boundary with Training Data')
create_contour_plot(mlp, train_X, train_Y, resolution=200)

print('Decision Boundary with Testing Data')
create_contour_plot(mlp, test_X, test_Y, resolution=200)
# Out:
# 1 iterations
# 2 iterations
# 3 iterations
# 4 iterations
# 5 iterations
# 6 iterations
# 7 iterations
# 8 iterations
# 9 iterations
# 10 iterations
# 11 iterations
# 12 iterations
# 13 iterations
# 14 iterations
# 15 iterations
# 16 iterations
# 17 iterations
# 18 iterations
# 19 iterations
# 20 iterations
# 21 iterations
# 22 iterations
# 23 iterations
# 24 iterations
# 25 iterations
# 26 iterations
# 27 iterations
# 28 iterations
# 29 iterations
# 30 iterations
# 31 iterations
# 32 iterations
# 33 iterations
# 34 iterations
# 35 iterations
# 36 iterations
# 37 iterations
# 38 iterations
# 39 iterations
# 40 iterations
# 41 iterations
# 42 iterations
# 43 iterations
# 44 iterations
# 45 iterations
# 46 iterations
# 47 iterations
# 48 iterations
# 49 iterations
# 50 iterations
# 51 iterations
# 52 iterations
# 53 iterations
# 54 iterations
# 55 iterations
# 56 iterations
# 57 iterations
# 58 iterations
# 59 iterations
# 60 iterations
# 61 iterations
# 62 iterations
# 63 iterations
# ...

# %% [markdown]
# #### Implement Multi Layer Perceptron Classifier on Handwritten Digit Recognition

# %%
# Load Training and Testing Data Sets
train_X = idx2numpy.convert_from_file(
    '../dataset/train-images.idx3-ubyte')
train_Y = idx2numpy.convert_from_file(
    '../dataset/train-labels.idx1-ubyte')
test_X = idx2numpy.convert_from_file(
    '../dataset/t10k-images.idx3-ubyte')
test_Y = idx2numpy.convert_from_file(
    '../dataset/t10k-labels.idx1-ubyte')

# %%
# Preprocess the image into input data format
train_X = preprocess_image(train_X)
test_X = preprocess_image(test_X)

# Fit the model
mlp = MLPClassifier(learning_rate=0.1, hidden_node_number=10, max_iterations=1000)
mlp.fit(train_X, train_Y)

pred_y = mlp.predict_class(test_X)

# Plot the data
plot_cost_vs_iteration(mlp)

# Performance Test
evaluate_model(test_Y, pred_y)

# %% [markdown]
# #### Implement Multi Layer Perceptron Classifier on Predicting Marketing Target

# %%
# Load Data
market_data = pd.read_csv('../dataset/Social_Network_Ads.csv', header=0)

# Remove the First Column
market_data = market_data.drop(market_data.columns[0], axis=1)

# Training Set
train_X = market_data.iloc[0:300, 0:-1].values
train_Y = market_data.iloc[0:300:, -1].values

# Test Set
test_X = market_data.iloc[300:, 0:-1].values
test_Y = market_data.iloc[300:, -1].values

# Standardize the Features for Both Training Set and Test Set
scaler = StandardScaler()

train_X = scaler.fit_transform(train_X)
test_X = scaler.transform(test_X)

# %%
# Fit the model
mlp = MLPClassifier(learning_rate=0.02, max_iterations=10000)
mlp.fit(train_X, train_Y)

# Plot the data
plot_cost_vs_iteration(mlp)

# Performance Test
pred_y = mlp.predict_class(test_X)
evaluate_model(test_Y, pred_y)

# Plot the decision boundary and the true labels
print('Decision Boundary with Training Data')
create_contour_plot(mlp, train_X, train_Y, resolution=200)

print('Decision Boundary with Testing Data')
create_contour_plot(mlp, test_X, test_Y, resolution=200)
# Out:
# 1 iterations
# 2 iterations
# 3 iterations
# 4 iterations
# 5 iterations
# 6 iterations
# 7 iterations
# 8 iterations
# 9 iterations
# 10 iterations
# 11 iterations
# 12 iterations
# 13 iterations
# 14 iterations
# 15 iterations
# 16 iterations
# 17 iterations
# 18 iterations
# 19 iterations
# 20 iterations
# 21 iterations
# 22 iterations
# 23 iterations
# 24 iterations
# 25 iterations
# 26 iterations
# 27 iterations
# 28 iterations
# 29 iterations
# 30 iterations
# 31 iterations
# 32 iterations
# 33 iterations
# 34 iterations
# 35 iterations
# 36 iterations
# 37 iterations
# 38 iterations
# 39 iterations
# 40 iterations
# 41 iterations
# 42 iterations
# 43 iterations
# 44 iterations
# 45 iterations
# 46 iterations
# 47 iterations
# 48 iterations
# 49 iterations
# 50 iterations
# 51 iterations
# 52 iterations
# 53 iterations
# 54 iterations
# 55 iterations
# 56 iterations
# 57 iterations
# 58 iterations
# 59 iterations
# 60 iterations
# 61 iterations
# 62 iterations
# 63 iterations
# ...
